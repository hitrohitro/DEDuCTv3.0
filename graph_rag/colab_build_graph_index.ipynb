# %% [markdown]
# # DEDuCTv3.0: Build Graph Index with Embeddings (Colab GPU)
# This notebook generates embeddings for your biological data and uploads them to Neo4j with automatic vector index creation.

# %%
# 1. Install dependencies
# !pip install sentence-transformers neo4j python-dotenv pandas networkx tqdm

# %% [markdown]
# ## 2. Mount Google Drive (if your data/code is there)
# Uncomment and run if needed.

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## 3. Upload your Supporting_Data and build_graph_index.py
# You can use the Colab file browser or Google Drive.

# %%
# Example: If using Google Drive, set your paths here
DATA_ROOT = '/content/drive/MyDrive/DEDuCTv3.0'  # Change as needed
SCRIPT_PATH = '/content/drive/MyDrive/DEDuCTv3.0/graph_rag/build_graph_index.py'
# !cp $SCRIPT_PATH ./build_graph_index.py

# %% [markdown]
# ## 4. Set Neo4j connection details
# Set your Neo4j URI, user, and password here.

# %%
import os
os.environ['NEO4J_URI'] = 'bolt://<YOUR_NEO4J_HOST>:7687'  # e.g., 'bolt://34.123.45.67:7687'
os.environ['NEO4J_USER'] = '<YOUR_NEO4J_USER>'
os.environ['NEO4J_PASSWORD'] = '<YOUR_NEO4J_PASSWORD>'

# %% [markdown]
# ## 5. Run the build_graph_index.py script
# This will generate embeddings using GPU and upload to Neo4j.

# %%
# !python build_graph_index.py --data-root $DATA_ROOT
